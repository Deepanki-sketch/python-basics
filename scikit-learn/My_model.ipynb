# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import (
    HistGradientBoostingRegressor,
    RandomForestRegressor
)
import joblib

# %%
housing = datasets.fetch_california_housing()

x = housing.data
y = housing.target

print("X shape:", x.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (20640, 8)
# Y shape: (20640,)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=432
)

lr = LinearRegression()

lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

r2_lr = r2_score(y_test, y_pred)

print("Linear Regression R²:", r2_lr)
# Out:
# Linear Regression R²: 0.6080229586580346

# %%
poly = PolynomialFeatures()

x_poly = poly.fit_transform(x)

print("Original:", x.shape)
print("Polynomial:", x_poly.shape)

x_train_poly, x_test_poly, y_train_poly, y_test_poly = train_test_split(
    x_poly,
    y,
    test_size=0.2,
    random_state=432
)

poly_model = LinearRegression()

poly_model.fit(x_train_poly, y_train_poly)

y_pred_poly = poly_model.predict(x_test_poly)

r2_poly = r2_score(y_test_poly, y_pred_poly)

print("Polynomial Regression R²:", r2_poly)
# Out:
# Original: (20640, 8)
# Polynomial: (20640, 45)
# Polynomial Regression R²: 0.5613546734924106

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=432
)

lr = LinearRegression()
gbr = HistGradientBoostingRegressor()
rfr = RandomForestRegressor(n_jobs=-1)

models = [lr, gbr, rfr]

for model in models:
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    r2 = r2_score(y_test, y_pred)

    print(type(model).__name__, "R²:", r2)
# Out:
# LinearRegression R²: 0.6080229586580346
# HistGradientBoostingRegressor R²: 0.8344175100206201
# RandomForestRegressor R²: 0.8143845013661148

# %%
model = HistGradientBoostingRegressor(
            max_iter=300,
            learning_rate=0.1, random_state=432
        )

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

r2 = r2_score(y_test, y_pred)

print(
            "max_iter:", 300,
            "learning_rate:", 0.1,
            "R²:", r2
        )
# Out:
# max_iter: 300 learning_rate: 0.1 R²: 0.8443686952344017

# %%
final_model = HistGradientBoostingRegressor(
    max_iter=300,
    learning_rate=0.1, random_state=432
)

final_model.fit(x_train, y_train)

y_pred = final_model.predict(x_test)

final_r2 = r2_score(y_test, y_pred)

print("Final R²:", final_r2)
# Out:
# Final R²: 0.8443686952344017

# %%
joblib.dump(final_model, "my_model.joblib")

print("Model saved!")
# Out:
# Model saved!

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\user\OneDrive\Desktop\CHAPTER1\scikit-learn

# %%
print(os.path.exists("my_model.joblib"))
# Out:
# True
