# %%
import joblib
model = joblib.load("my_model.joblib")
print(model)

new_data = [[3.14,5.72,11,12,1,29,6,5]]
prediction = model.predict(new_data)
print("Prediction:", prediction)
# Out:
# HistGradientBoostingRegressor(max_iter=300, random_state=432)
# Prediction: [0.88503968]
